# %%
import polars as pl

def preprocess_data():
    df = pl.read_csv("data.csv")

# %%
df = pl.read_csv("./data/DataCoSupplyChainDataset.csv", separator=",",ignore_errors=True, encoding="latin-1")
df
# Out:
# shape: (180_519, 53)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Type     ┆ Days for  ┆ Days for  ┆ Benefit   ┆ … ┆ Product   ┆ Product   ┆ shipping  ┆ Shipping  │
# │ ---      ┆ shipping  ┆ shipment  ┆ per order ┆   ┆ Price     ┆ Status    ┆ date (Dat ┆ Mode      │
# │ str      ┆ (real)    ┆ (schedule ┆ ---       ┆   ┆ ---       ┆ ---       ┆ eOrders)  ┆ ---       │
# │          ┆ ---       ┆ d)        ┆ f64       ┆   ┆ f64       ┆ i64       ┆ ---       ┆ str       │
# │          ┆ i64       ┆ ---       ┆           ┆   ┆           ┆           ┆ str       ┆           │
# │          ┆           ┆ i64       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ DEBIT    ┆ 3         ┆ 4         ┆ 91.25     ┆ … ┆ 327.75    ┆ 0         ┆ 2/3/2018  ┆ Standard  │
# ...

# %%
df.write_delta("./data/processed_data.delta")

# %%
df = pl.read_delta("./data/processed_data.delta")

# %%
df
# Out:
# shape: (180_519, 53)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Type     ┆ Days for  ┆ Days for  ┆ Benefit   ┆ … ┆ Product   ┆ Product   ┆ shipping  ┆ Shipping  │
# │ ---      ┆ shipping  ┆ shipment  ┆ per order ┆   ┆ Price     ┆ Status    ┆ date (Dat ┆ Mode      │
# │ str      ┆ (real)    ┆ (schedule ┆ ---       ┆   ┆ ---       ┆ ---       ┆ eOrders)  ┆ ---       │
# │          ┆ ---       ┆ d)        ┆ f64       ┆   ┆ f64       ┆ i64       ┆ ---       ┆ str       │
# │          ┆ i64       ┆ ---       ┆           ┆   ┆           ┆           ┆ str       ┆           │
# │          ┆           ┆ i64       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ DEBIT    ┆ 3         ┆ 4         ┆ 91.25     ┆ … ┆ 327.75    ┆ 0         ┆ 2/3/2018  ┆ Standard  │
# ...
